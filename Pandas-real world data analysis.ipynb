# %%
import pandas as pd

# %%
#import single month file

data_apr = pd.read_csv('./sales_data/sales_april_2019.csv')
data_apr.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
# if we want all the file from the folder or the directory than need to import 'os'

import os

# %%
files = [file for file in os.listdir('./sales_data')]
for file in files:
    print(file)
# Out:
# Sales_December_2019.csv
# Sales_April_2019.csv
# Sales_February_2019.csv
# Sales_March_2019.csv
# Sales_August_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_January_2019.csv
# Sales_September_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv

# %%
# pandas concatenation to one file.

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('./sales_data/' + file)
    all_months_data = pd.concat([all_months_data,df])

# %%
all_months_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %%
# to check if the file is merged or not we can save the file and check.

all_months_data.to_csv('all_data.csv',index = False)

# data is merged in the new file.

# %%
all_data = pd.read_csv('all_data.csv')
all_data.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each      Order Date  \
# 0   295665    Macbook Pro Laptop                1       1700  12/30/19 00:01
# 1   295666    LG Washing Machine                1      600.0  12/29/19 07:03
# 2   295667  USB-C Charging Cable                1      11.95  12/12/19 18:21
# 3   295668      27in FHD Monitor                1     149.99  12/22/19 15:13
# 4   295669  USB-C Charging Cable                1      11.95  12/18/19 12:38
#
#                          Purchase Address
# 0  136 Church St, New York City, NY 10001
# 1     562 2nd St, New York City, NY 10001
# 2    277 Main St, New York City, NY 10001
# 3     410 6th St, San Francisco, CA 94016
# 4           43 Hill St, Atlanta, GA 30301

# %% [markdown]
# Augment Data with additional column

# %% [markdown]
# ### Data Cleanup

# %%
# before we do analysis need to clean & augment new column as required
all_data['Month'] = all_data['Order Date'].str[0:2]!='Or'

# %%
# we need month column from the order date

all_data['Month']= all_data['Order Date'].str[0:2]
all_data['Month']= all_data['Month'].astype('int64')
all_data['Month'].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-31d0055d64a1> in <module>
#       2
#       3 all_data['Month']= all_data['Order Date'].str[0:2]
# ----> 4 all_data['Month']= all_data['Month'].astype('int64')
#       5 all_data['Month'].head()
#       6
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# ...

# %% [markdown]
# Find 'Or' & delete it

# %%
temp_data = all_data[all_data['Order Date'].str[0:2]== 'Or']
temp_data.head()
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 254   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 705   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1101  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2875  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3708  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address Month
# 254   Purchase Address    Or
# 705   Purchase Address    Or
# 1101  Purchase Address    Or
# 2875  Purchase Address    Or
# 3708  Purchase Address    Or

# %%
# we can remove the 'Or'rows

all_data = all_data[all_data['Order Date'].str[0:2] != 'Or']

# %%
# we can re enter the Month augment code to chek if the data is clean now.
all_data['Month']= all_data['Order Date'].str[0:2]
all_data['Month']= all_data['Month'].astype('int64')
all_data['Month'].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-9e82699746e6> in <module>
#       1 # we can re enter the Month augment code to chek if the data is clean now.
#       2 all_data['Month']= all_data['Order Date'].str[0:2]
# ----> 3 all_data['Month']= all_data['Month'].astype('int64')
#       4 all_data['Month'].head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
# ...

# %%
# Find NaN values in the data

df1 = all_data[all_data.isna().any(axis=1)]
df1.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address  \
# 264       NaN     NaN              NaN        NaN        NaN              NaN
# 648       NaN     NaN              NaN        NaN        NaN              NaN
# 680       NaN     NaN              NaN        NaN        NaN              NaN
# 1385      NaN     NaN              NaN        NaN        NaN              NaN
# 1495      NaN     NaN              NaN        NaN        NaN              NaN
#
#      Month
# 264    NaN
# 648    NaN
# 680    NaN
# 1385   NaN
# 1495   NaN

# %%
# drop Nan values:
all_data = all_data.dropna(how = 'all')

# Rewrite the month code to chek 
all_data['Month']= all_data['Order Date'].str[0:2]
all_data['Month']= all_data['Month'].astype('int64')
all_data['Month'].head()

# month column is successfully Augmented.
# Out:
# 0    12
# 1    12
# 2    12
# 3    12
# 4    12
# Name: Month, dtype: int64

# %%
# to answer the #Q1 we need a sales column
# quantity ordered * each price

all_data['Sales'] = all_data['Quantity Ordered']* all_data['Price Each']
all_data.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# ...

# %%
# for the above error we need to convert from str to int
# this code will convert to int as well as float.

all_data['Quantity Ordered'] = pd.to_numeric(all_data['Quantity Ordered'])

all_data['Price Each'] = pd.to_numeric(all_data['Price Each'])

# %%
# Re-enter the sales column code to check
all_data['Sales'] = all_data['Quantity Ordered']* all_data['Price Each']
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month    Sales
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12    11.95

# %% [markdown]
# DATA- ANALYSIS

# %% [markdown]
# ### Q1 what was the bestmonth for sales? how was earned that month ?

# %%
# ANS: Dec month has highest sales & Jan has the lowest sale.

result = all_data.groupby('Month').sum()
result
# Out:
#        Quantity Ordered    Price Each         Sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
# we can visualize the above sale by matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
months = range(1,13)

plt.bar(months,result['Sales'])
plt.xticks(months)
plt.xlabel('months in number')
plt.ylabel('sales value in ($US)')

plt.show()

# %% [markdown]
# ### Q2- what city had the highest number of sales?

# %%
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month    Sales
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12    11.95

# %%
# Need city column from address.

all_data['City'] = all_data['Purchase Address'].str.split(',').apply(lambda x: x[1])

all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address  Month    Sales  \
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001     12  1700.00
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001     12   600.00
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001     12    11.95
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016     12   149.99
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301     12    11.95
#
#              City
# 0   New York City
# 1   New York City
# 2   New York City
# 3   San Francisco
# 4         Atlanta

# %%
# ANS Q2:

result1 = all_data.groupby('City').sum()
result1
# Out:
#                 Quantity Ordered    Price Each   Month         Sales
# City
#  Atlanta                   16602  2.779908e+06  104794  2.795499e+06
#  Austin                    11153  1.809874e+06   69829  1.819582e+06
#  Boston                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles               33289  5.421435e+06  208325  5.452571e+06
#  New York City             27932  4.635371e+06  175741  4.664317e+06
#  Portland                  14053  2.307747e+06   87765  2.320491e+06
#  San Francisco             50239  8.211462e+06  315520  8.262204e+06
#  Seattle                   16553  2.733296e+06  104941  2.747755e+06

# %%
cities = [city for city,df in all_data.groupby('City')]
plt.bar(cities,result1['Sales'])
plt.xticks(cities,rotation = 'vertical')
plt.xlabel('cities name')
plt.ylabel('sales value in ($US)')

plt.show()

# %% [markdown]
# ### Q3 - what time should we display advertisements to maximize likelihood of customer's buying product?

# %%
# to Ans Q3 first we need hour column:-

all_data['Order Date']= pd.to_datetime(all_data['Order Date'])

# %%
all_data['Hour']= all_data['Order Date'].dt.hour
all_data.head()
# Out:
#   Order ID               Product  Quantity Ordered  Price Each  \
# 0   295665    Macbook Pro Laptop                 1     1700.00
# 1   295666    LG Washing Machine                 1      600.00
# 2   295667  USB-C Charging Cable                 1       11.95
# 3   295668      27in FHD Monitor                 1      149.99
# 4   295669  USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  Month    Sales  \
# 0 2019-12-30 00:01:00  136 Church St, New York City, NY 10001     12  1700.00
# 1 2019-12-29 07:03:00     562 2nd St, New York City, NY 10001     12   600.00
# 2 2019-12-12 18:21:00    277 Main St, New York City, NY 10001     12    11.95
# 3 2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016     12   149.99
# 4 2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301     12    11.95
#
#              City  Hour
# 0   New York City     0
# 1   New York City     7
# 2   New York City    18
# ...

# %%
result2 = all_data.groupby('Hour').count()
result2
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# Hour
# 0         3910     3910              3910        3910        3910
# 1         2350     2350              2350        2350        2350
# 2         1243     1243              1243        1243        1243
# 3          831      831               831         831         831
# 4          854      854               854         854         854
# 5         1321     1321              1321        1321        1321
# 6         2482     2482              2482        2482        2482
# 7         4011     4011              4011        4011        4011
# 8         6256     6256              6256        6256        6256
# 9         8748     8748              8748        8748        8748
# 10       10944    10944             10944       10944       10944
# 11       12411    12411             12411       12411       12411
# 12       12587    12587             12587       12587       12587
# ...

# %%
hours = [hour for hour,df in all_data.groupby('Hour')]
plt.plot(hours,result2['Sales'])
plt.xticks(hours)
plt.xlabel('hours')
plt.ylabel('Number of orders)')
plt.grid()
plt.show()
